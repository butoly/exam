# %%
import pandas as pd

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 162857      ZWE    Africa     Zimbabwe  2022-02-14     231603.0      222.0
# 162858      ZWE    Africa     Zimbabwe  2022-02-15     231603.0        0.0
# 162859      ZWE    Africa     Zimbabwe  2022-02-16     232213.0      610.0
# 162860      ZWE    Africa     Zimbabwe  2022-02-17     232598.0      385.0
# 162861      ZWE    Africa     Zimbabwe  2022-02-18     233030.0      432.0
#
# ...

# %%
df[df.continent=="Asia"].groupby("location")["new_cases"].agg("sum")
# Out:
# location
# Afghanistan               171857.0
# Armenia                   413295.0
# Azerbaijan                768019.0
# Bahrain                   485163.0
# Bangladesh               1929154.0
# Bhutan                      9210.0
# Brunei                     27599.0
# Cambodia                  125201.0
# China                     106965.0
# Georgia                  1526205.0
# Hong Kong                  21750.0
# India                   42802505.0
# Indonesia                5089637.0
# Iran                     6913427.0
# Iraq                     2288777.0
# Israel                   3523457.0
# Japan                    4337778.0
# Jordan                   1553758.0
# Kazakhstan               1384317.0
# Kuwait                    610801.0
# Kyrgyzstan                200287.0
# Laos                      140604.0
# Lebanon                  1039299.0
# Macao                         78.0
# Malaysia                 3166023.0
# Maldives                  163581.0
# ...

# %%
#среднее по стране
df[df.continent=='Asia'].groupby('location')['new_deaths'].mean()
# Out:
# location
# Afghanistan              10.782235
# Armenia                  11.910791
# Azerbaijan               12.968927
# Bahrain                   2.035461
# Bangladesh               41.153627
# Bhutan                    0.012285
# Brunei                    0.141414
# Cambodia                  8.739130
# China                     6.093668
# Georgia                  22.989796
# Hong Kong                 0.345845
# India                   710.657264
# Indonesia               205.695775
# Iran                    184.140903
# Iraq                     34.644351
# Israel                   14.019971
# Japan                    29.127544
# Jordan                   19.638329
# Kazakhstan               27.162824
# Kuwait                    3.683673
# Kyrgyzstan                4.282387
# Laos                      2.115385
# Lebanon                  13.964838
# Macao                          NaN
# Malaysia                 45.846591
# Maldives                  0.438729
# ...

# %%
# Среднее по материку
avg_continent = df[df.continent=='Asia'].groupby('continent')['new_deaths'].mean()[0]
print(avg_continent)
# Out:
# 42.64255647312105

# %%
variable = df[df.continent=='Asia'].groupby('location')['new_deaths'].mean()
variable[variable < 42]
# Out:
# location
# Afghanistan             10.782235
# Armenia                 11.910791
# Azerbaijan              12.968927
# Bahrain                  2.035461
# Bangladesh              41.153627
# Bhutan                   0.012285
# Brunei                   0.141414
# Cambodia                 8.739130
# China                    6.093668
# Georgia                 22.989796
# Hong Kong                0.345845
# Iraq                    34.644351
# Israel                  14.019971
# Japan                   29.127544
# Jordan                  19.638329
# Kazakhstan              27.162824
# Kuwait                   3.683673
# Kyrgyzstan               4.282387
# Laos                     2.115385
# Lebanon                 13.964838
# Maldives                 0.438729
# Mongolia                 5.172662
# Myanmar                 28.002899
# Nepal                   18.498447
# Oman                     6.123188
# Palestine                7.707914
# Qatar                    0.953824
# ...
